# %%
horoscopes_list = ["Luck is coming your way", "You will run into someone who will become a large part of your life soon.", "You will choose to step out of your comfort zone soon and it will lead to a great experience"]
zodiacSign_list = ["Aquarius", "Pisces", "Aries", "Taurus", "Gemini", "Cancer", "Leo", "Virgo", "Libra", "Scorpio", "Sagittarius", "Cancer"]
zodiacSign = ""
from random import randrange
randomHoro = (randrange(3))
   
birthMonth = int( input ("Enter your birth month "))
birthDay = int (input ("Enter the day of the month that you were born "))
    
if birthMonth == 1:                         #January
    if birthDay <= 19:
        zodiacSign = zodiacSign_list[11]
    if birthDay > 19:
        zodiacSign = zodiacSign_list[0]
if birthMonth == 2:                         #Febuary
    if birthDay <= 18:
        zodiacSign = zodiacSign_list[0]
    if birthDay >= 19:
        zodiacSign = zodiacSign_list[1]
if birthMonth == 3:                         #Marth
    if birthDay <= 19:
        zodiacSign = zodiacSign_list[1]
    if birthDay > 19:
        zodiacSign = zodiacSign_list[2]
if birthMonth == 4:                         #April
    if birthDay <= 19:
        zodiacSign = zodiacSign_list[2]
    if birthDay > 19:
        zodiacSign = zodiacSign_list[3]
if birthMonth == 5:                         #May
    if birthDay <= 20:
        zodiacSign = zodiacSign_list[3]
    if birthDay > 20:
        zodiacSign = zodiacSign_list[4]
if birthMonth == 6:                         #June
    if birthDay <= 20:
        zodiacSign = zodiacSign_list[4]
    if birthDay > 20:
        zodiacSign = zodiacSign_list[5]
if birthMonth == 7:                         #July
    if birthDay <= 23:
        zodiacSign = zodiacSign_list[4]
    if birthDay > 23:
        zodiacSign = zodiacSign_list[5]
if birthMonth == 7:                         #June
    if birthDay <= 22:
        zodiacSign = zodiacSign_list[5]
    if birthDay > 22:
        zodiacSign = zodiacSign_list[6]
if birthMonth == 8:                         #August
    if birthDay <= 22:
        zodiacSign = zodiacSign_list[6]
    if birthDay > 22:
        zodiacSign = zodiacSign_list[7]
if birthMonth == 9:                         #September
    if birthDay <= 22:
        zodiacSign = zodiacSign_list[7]
    if birthDay > 22:
        zodiacSign = zodiacSign_list[8]
if birthMonth == 10:                         #October
    if birthDay <= 22:
        zodiacSign = zodiacSign_list[8]
    if birthDay > 22:
        zodiacSign = zodiacSign_list[9]
if birthMonth == 11:                         #November
    if birthDay <= 21:
        zodiacSign = zodiacSign_list[9]
    if birthDay > 21:
        zodiacSign = zodiacSign_list[10]
if birthMonth == 12:                         #December
    if birthDay <= 21:
        zodiacSign = zodiacSign_list[10]
    if birthDay > 21:
        zodiacSign = zodiacSign_list[11]
        
    
print ("Your birthday month is", birthMonth)
print ("Your day of birth is ", birthDay)
print ("Your zodiac sign is", zodiacSign)
print ("Your horoscope is:")
print (horoscopes_list [randomHoro])
# Out:
# Enter your birth month 11
# Enter the day of the month that you were born 13
# Your birthday month is 11
# Your day of birth is  13
# Your zodiac sign is Scorpio
# Your horoscope is:
# You will choose to step out of your comfort zone soon and it will lead to a great experience
